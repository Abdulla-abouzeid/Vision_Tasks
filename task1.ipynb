# %%
import cv2,numpy as np

img=cv2.imread("C:/Users/Abdul/Downloads/download (1).jpg")
img2=cv2.imread("C:/Users/Abdul/Downloads/download.jpg")
img3=cv2.imread("C:/Users/Abdul/Downloads/download1.jpg")

# %%
print(img.shape)
print(img.dtype)
print(img.ndim)
# Out:
# (225, 225, 3)
# uint8
# 3

# %%
h, w = img.shape[:2]
total=h*w
total
# Out:
# 50625

# %%
img.size
# Out:
# 151875

# %%
bgr_pixel=img[200,206]
bgr_pixel
# Out:
# array([ 0, 16, 27], dtype=uint8)

# %%
img_f=img.astype('float32')
img_f
# Out:
# array([[[180., 200., 211.],
#         [180., 200., 211.],
#         [180., 200., 211.],
#         ...,
#         [179., 199., 210.],
#         [179., 199., 210.],
#         [178., 200., 211.]],
#
#        [[180., 200., 211.],
#         [180., 200., 211.],
#         [180., 200., 211.],
#         ...,
#         [179., 199., 210.],
#         [179., 199., 210.],
#         [178., 200., 211.]],
#
#        [[180., 200., 211.],
#         [180., 200., 211.],
#         [180., 200., 211.],
#         ...,
#         [179., 199., 210.],
#         [179., 199., 210.],
#         [178., 200., 211.]],
#
#        ...,
#
#        [[  6.,  46.,  51.],
#         [  7.,  47.,  52.],
#         [  7.,  47.,  52.],
#         ...,
#         [ 30.,  79.,  95.],
#         [ 33.,  80.,  94.],
#         [ 28.,  73.,  84.]],
#
#        [[ 11.,  53.,  60.],
#         [ 10.,  52.,  57.],
#         [ 11.,  50.,  58.],
#         ...,
#         [  2.,  51.,  67.],
#         [  3.,  52.,  66.],
# ...

# %%
R=img[:,:,2]
B=img[:,:,0]
G=img[:,:,1]
print(R)
# Out:
# [[211 211 211 ... 210 210 211]
#  [211 211 211 ... 210 210 211]
#  [211 211 211 ... 210 210 211]
#  ...
#  [ 51  52  52 ...  95  94  84]
#  [ 60  57  58 ...  67  66  78]
#  [ 65  67  76 ...  59  65  61]]

# %%
cv2.imshow('Abdulla',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray=cv2.imread("C:/Users/Abdul/Downloads/download (1).jpg",0)
cv2.imshow('Abdulla',gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
color=cv2.imread("C:/Users/Abdul/Downloads/download (1).jpg",1)
cv2.imshow('Abdulla',gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
rgba=cv2.imread("C:/Users/Abdul/Downloads/download (1).jpg",-1)
cv2.imshow('Abdulla',gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
new_img=cv2.imwrite('abdulla.jpg',img)
